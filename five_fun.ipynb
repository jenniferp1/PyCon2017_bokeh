# %% [markdown]
# # Introduction to bokeh
#
# ## Top 5 fun and entertaining plots
# ---
#
# <img src='./images/logos.3.600.wide.png' height='250' width='300' style="float:right">

# %% [markdown]
# Next, we will take a look at five sample plots include many diverse examples of how bokeh can be used for awesome data visualizations.
#    0. **scatterplot**
#    1. **histogram** with pdf and cdf curves
#    2. graph with **interactive sliders** to set parameters
#    3. **visualization tools**: pan, zoom, hover, crosshairs, lasso select, box select, poly select, save, undo, redo, tap
#    4. **geographical map**
#
#
# This material is based largely upon the sample graphs shown here:
# http://bokeh.pydata.org/en/latest/docs/gallery.html

# %% [markdown]
# # Sample data for your amusement is available:

# %% [markdown]
# Bokeh comes preinstalled with various types of sample data: look in the site-packages folder found in your virtual environment folder...
#
# `<path_to_where_you_installed_miniconda>/miniconda3/envs/bokeh_tut/lib/python3.5/site-packages/bokeh/sampledata/`
#
# Bokeh provides ready access to some of the smaller datasets via import, as we will see.
#
# There are other much larger datasets available as well, that we will be using and will get later, using:
#
# `bokeh.sampledata.download()`

# %% [markdown]
# # Simple scatterplot
# ---
#
# <img src='./images/220px-Iris_versicolor_3.jpg' height='250' width='300' style="float:right">

# %%
# Let's start by importing some of the data

from bokeh.plotting import figure, show, output_notebook
from bokeh.sampledata.iris import flowers

# When flowers is imported, it comes in as a pandas DataFrame
# DataFrames have a function called sample, that will let us see a representative
#     sample of all the data... let's look at 10 rows.

print(type(flowers))
print(len(flowers))
flowers.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 150
#      sepal_length  sepal_width  petal_length  petal_width     species
# 50            7.0          3.2           4.7          1.4  versicolor
# 10            5.4          3.7           1.5          0.2      setosa
# 127           6.1          3.0           4.9          1.8   virginica
# 91            6.1          3.0           4.6          1.4  versicolor
# 111           6.4          2.7           5.3          1.9   virginica
# 64            5.6          2.9           3.6          1.3  versicolor
# 99            5.7          2.8           4.1          1.3  versicolor
# 78            6.0          2.9           4.5          1.5  versicolor
# 43            5.0          3.5           1.6          0.6      setosa
# 146           6.3          2.5           5.0          1.9   virginica

# %%
# Next, we will prep some enrichments that we can apply to our flower data
# We want to map the species of iris to a color so we create a dict.

colormap = {'setosa': 'red',
            'versicolor': 'green',
            'virginica': 'blue'}

# Then we create a list of colors... one color for each row in the flowers DataFrame.
# Based on the species in the species column, we insert the appropriate color
# into our list.

colors = [colormap[x] for x in flowers['species']]

# To see the results of our work, let's look at a sampling of the colors list.

print(len(colors))
colors[::10]
# Out:
# 150
# ['red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue']

# %%
p = figure(title = "Iris Morphology")

p.xaxis.axis_label = 'Petal Length'
p.yaxis.axis_label = 'Petal Width'

p.circle(flowers["petal_length"],      # x values
         flowers["petal_width"],       # y values
         color=colors, 
         fill_alpha=0.2, 
         size=10)
# Out:
# GlyphRenderer(id='9fd5b4bc-0a1c-4b38-98a0-b86d3e332bcb', ...)

# %%
output_notebook()
show(p)

# http://bokeh.pydata.org/en/latest/docs/gallery/iris.html
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6fd0a4cb-6e45-4e08-a62a-ba22b92a4ab9">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e482b586-1b26-4897-ac6b-85205cf689b7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e482b586-1b26-4897-ac6b-85205cf689b7");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e482b586-1b26-4897-ac6b-85205cf689b7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e482b586-1b26-4897-ac6b-85205cf689b7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bd5131b9-8f01-47e4-8f2c-59c2a1091cab":{"roots":{"references":[{"attributes":{"plot":{"id":"6f86085b-a822-4b17-8229-fb318a88baa8","subtype":"Figure","type":"Plot"}},"id":"2796147d-74bf-4cd1-8112-4539a4e0685b","type":"HelpTool"},{"attributes":{"callback":null},"id":"01938589-fc05-4c02-9613-aab0a89eb832","type":"DataRange1d"},{"attributes":{"axis_label":"Petal Length","formatter":{"id":"7bfbc6ce-4fe2-4f54-a76e-54e591292f8e","type":"BasicTickFormatter"},"plot":{"id":"6f86085b-a822-4b17-8229-fb318a88baa8","subtype":"Figure","type":"Plot"},"ticker":{"id":"7aaed2bd-91de-4dba-8459-92ae05ecfb4a","type":"BasicTicker"}},"id":"ebfa990d-29ea-475e-8aef-a4d3afdf9637","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y","fill_color","line_color"],"data":{"fill_color":["red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue"],"line_color":["red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue"],"x":{"__ndarray__":"...","dtype":"float64","shape":[150]},"y":{"__ndarray__":"...","dtype":"float64","shape":[150]}}},"id":"c3ce6281-6691-4baf-ac18-49c05715803e","type":"ColumnDataSource"},{"attributes":{},"id":"e10c86ac-b127-4540-98ae-4b31ea172860","type":"ToolEvents"},{"attributes":{"overlay":{"id":"6f3bcc48-bd61-4087-8b12-f9b581b62cbf","type":"BoxAnnotation"},"plot":{"id":"6f86085b-a822-4b17-8229-fb318a88baa8","subtype":"Figure","type":"Plot"}},"id":"b0f5e7fc-85bc-43e3-b072-c78c009b1e94","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"6f86085b-a822-4b17-8229-fb318a88baa8","subtype":"Figure","type":"Plot"},"ticker":{"id":"7aaed2bd-91de-4dba-8459-92ae05ecfb4a","type":"BasicTicker"}},"id":"55980d5d-96f7-4342-af85-7b332e661954","type":"Grid"},{"attributes":{"below":[{"id":"ebfa990d-29ea-475e-8aef-a4d3afdf9637","type":"LinearAxis"}],"left":[{"id":"584b4c7a-d484-4f22-9746-98e5f4edd9a7","type":"LinearAxis"}],"renderers":[{"id":"ebfa990d-29ea-475e-8aef-a4d3afdf9637","type":"LinearAxis"},{"id":"55980d5d-96f7-4342-af85-7b332e661954","type":"Grid"},{"id":"5 ...

# %% [markdown]
# # Workflow
# ---

# %% [markdown]
# As we look at the remaining examples, and as you create your own, a generic, but useful workflow is listed below. Following a workflow such as this, helps you to focus on one task at a time and create robust and easy to understand scripts.
#
# 1. Import libraries
# 1. Generate a figure
# 1. Create or load data and enrichments
# 1. Generate glyphs
# 1. Add attributes, annotations, interactions
# 1. Create outputs
#
# **NOTES**:
#
# * You may not need some steps in the above workflow, especially for barebones charts.
# * Conversely, your charts may be very sophisticated and you may need to expand on the above workflow.
# * This is intended as a starting point.
# * Your mileage may vary (YMMV)!

# %% [markdown]
# # Histogram: with pdf and cdf curves
# ---

# %%
# IMPORTS ---------------------------------------

import numpy as np
import scipy.special

from bokeh.layouts import gridplot
from bokeh.plotting import figure, show, output_notebook

# %%
# GENERATE FIGURE -----------------------------------------

h = figure(title="Normal Distribution (μ=0, σ=0.5)",
            tools="save",
            background_fill_color="whitesmoke")

# Notice this creates a figure() object

h
# Out:
# Figure(id='37f7ede6-1930-4f68-99a5-866878614b19', ...)

# %% [markdown]
# ```
# h?
# ```
#
# versus
#
# ```
# h??
# ```

# %%
# CREATE OR LOAD DATA/ENRICHMENTS -------------------------

# set the midpoint and spread of the data
mu, sigma = 0, 0.5

# draw a 1000 random samples from a normal distribution 
measured = np.random.normal(mu, sigma, 1000)

# compute the histogram of a set of data.
#     hist is an array of the y-values of the histogram points
#     edges is an array of the 'sides' of the rectangles as 
#     defined across the x-axis
hist, edges = np.histogram(measured, density=True, bins=50)

# create an array of x-values: 1000 values between -2 and 2
x = np.linspace(-2, 2, 1000)

# calculate the points for a pdf and a cdf based on:
#     * mu
#     * sigma
#     * the values of x
pdf = 1/(sigma * np.sqrt(2*np.pi)) * np.exp(-(x-mu)**2 / (2*sigma**2))
cdf = (1+scipy.special.erf((x-mu)/np.sqrt(2*sigma**2)))/2

print('MEASURED: ', measured[:10])
print()
print('HIST: ', len(hist), hist[:10])
print()
print('EDGES: ', len(edges), edges[:10])
print()
print('-' * 60, end='\n\n')
print('PDF: ', pdf[:10])
print()
print('CDF: ', cdf[:10])
# Out:
# MEASURED:  [-0.12719752  0.59646931  0.40942059 -0.44822771  0.3908836  -0.45965912
#   0.73881379  0.82145547  0.38931192  0.6012291 ]
#
# HIST:  50 [ 0.0508381   0.          0.01694603  0.0508381   0.          0.06778413
#   0.01694603  0.10167619  0.06778413  0.08473016]
#
# EDGES:  51 [-1.58371829 -1.52470743 -1.46569656 -1.4066857  -1.34767484 -1.28866397
#  -1.22965311 -1.17064225 -1.11163138 -1.05262052]
#
# ------------------------------------------------------------
#
# PDF:  [ 0.00026766  0.00027636  0.00028533  0.00029457  0.00030409  0.0003139
#   0.000324    0.00033441  0.00034513  0.00035617]
#
# CDF:  [  3.16712418e-05   3.27602929e-05   3.38847210e-05   3.50456008e-05
#    3.62440370e-05   3.74811655e-05   3.87581535e-05   4.00762007e-05
#    4.14365401e-05   4.28404387e-05]

# %% [markdown]
# # Experience Points
# ---

# %% [markdown]
# 1. In the code cell below, use `?` to explore the `quad()` function assocated with the figure `h`
# 1. What is the default fill_color?
# 1. What does the characteristic `alpha` do?
# 1. How does `alpha` contrast with `line_alpha`?

# %%
# Let's look into the quad() method of our figure:
h??

# %%
# GENERATE GLYPHS -----------------------------------------

h.quad(top=hist,
       bottom=0,
       left=edges[:-1],
       right=edges[1:],
       fill_color='yellow', alpha=0.9, line_color="orange")
# Out:
# GlyphRenderer(id='faebc058-9ed6-44a2-b395-aa3252f3b6b3', ...)

# %%
# GENERATE GLYPHS (cont.)-----------------------------------

h.line(x, pdf, line_color="black", line_width=3, alpha=0.7, legend="PDF")
h.line(x, cdf, line_color="red", line_width=2, alpha=0.7, legend="CDF")
# Out:
# GlyphRenderer(id='90a1ee4f-c817-4825-b2cf-d6e0b8e05f0b', ...)

# %%
# ADD ATTRIBUTES, ANNOTATIONS, INTERACTIONS ---------------

h.legend.location = "top_left"
h.xaxis.axis_label = 'x'
h.yaxis.axis_label = 'Pr(x)'

# %%
# CREATE OUTPUTS ------------------------------------------
output_notebook()
show(h)

# http://bokeh.pydata.org/en/latest/docs/gallery/histogram.html
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4c88f0ec-3e31-4e3d-8760-89ff139d80ae">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5e6aeabe-6845-4441-a618-7e0f8ce35229"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("5e6aeabe-6845-4441-a618-7e0f8ce35229");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5e6aeabe-6845-4441-a618-7e0f8ce35229");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5e6aeabe-6845-4441-a618-7e0f8ce35229' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"369a0a14-c354-4fea-966b-75209cf56234":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"9f2bb9b0-dd18-475b-bb10-d0b70a39924c","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"4525634e-30c3-4fa9-8c1a-fa134bc578da","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"0c603799-e556-4117-a2bf-7e760e8772d0","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.7},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"70286358-dc84-47c4-ba2d-fe5d8712bb23","type":"Line"},{"attributes":{"data_source":{"id":"4525634e-30c3-4fa9-8c1a-fa134bc578da","type":"ColumnDataSource"},"glyph":{"id":"08972076-3cc2-482e-ab50-a7e974ce1c0c","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"21d30508-a903-48d7-a090-311c45bf20db","type":"Line"},"selection_glyph":null},"id":"90a1ee4f-c817-4825-b2cf-d6e0b8e05f0b","type":"GlyphRenderer"},{"attributes":{"axis_label":"x","formatter":{"id":"99ec5f92-4392-4436-a4f2-4b4742c4a67d","type":"BasicTickFormatter"},"plot":{"id":"37f7ede6-1930-4f68-99a5-866878614b19","subtype":"Figure","type":"Plot"},"ticker":{"id":"2593907a-b406-40b7-9d12-0410a1cf2e45","type":"BasicTicker"}},"id":"5c0a1a36-3c51-49ff-a411-9eac332c05d9","type":"LinearAxis"},{"attributes":{"callback":null},"id":"549caf2f-232d-4a91-aa18-ed4504658a37","type":"DataRange1d"},{"attributes":{"data_source":{"id":"c26d3847-5696-4283-9f8d-cbd379d83779","type":"ColumnDataSource"},"glyph":{"id":"cddfc33c-1296-46c7-a7b7-542c0bd0445f","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d04399af-b771-469b-a86d-1d3eb1463823","type":"Quad"},"selection_glyph":null},"id":"faebc058-9ed6-44a2-b395-aa3252f3b6b3","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"58eb4a7c-738f-4bd6-b5a9-5b26ef60adde","type":"ColumnDataSource"},{"attributes":{"background_fill_color":{"value":"whitesmoke"},"below":[{"id":"5c0a1a36-3c51-49ff-a411-9eac332c05d9","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"383186ab-810e-471d-abbd-4a6cf2852478","type":"LinearAxis"}],"renderers":[{"id":"5c0a1a36-3c51-49ff-a411-9eac332c05d9","type":"LinearAxis"},{"id":"b5b3e6e9-fc8e-4732-94d4-17b769d80e59","type":"Grid"},{"id":"383186ab-810e-471d-abbd-4a6cf2852478","type":"LinearAxis"},{"id":"4bc788a9-6450-4916-adce-9baedfbb1220","type":"Grid"},{"id":"44553e35-eaa6-4430-8adf-0c7d3cad4fef","type":"GlyphRenderer"},{"id":"c6c226fd-343b-4da4-bdf8-1a70b8b7b12f","type":"Legend"},{"id":"5e1018f8-1a4b-4cfb-ac6c-a831134d0bcd","type":"GlyphRenderer"},{"id":"4de34e61-50f4-403d-9098-0506097effc6","type":"GlyphRenderer"},{"id":"9e38830e-91a1-4caf-8d9c-c9c921fabf63","type":"GlyphRenderer"},{"id":"e1172644-cd85-40e1-8b77-cfe6eea7f28c","type":"GlyphRenderer"},{"id":"247fd0ee-1028-4558-92e5-788431f3e2cc","type":"GlyphRenderer"},{"id":"faebc058-9ed6-44a2-b395-aa3252f3b6b3","type":"GlyphRenderer"},{"id":"e5b983e6-eb3c-4f4e-a9ae-de1df126f340","type":"GlyphRenderer"},{"id":"90a1ee4f-c817-4825-b2cf-d6e0b8e05f0b","type":"GlyphRenderer"}],"title":{"id":"e9a0474e-4e7b-4c8c-9962-3a4050752f26","type":"Title"},"tool_events":{"id":"776fd448-d7ad-4956-92a3-2db4b3f505aa","type":"ToolEvents"},"toolbar":{"id":"2a3c419c-a6e5-4c73-b8a1-60acfcec58d5","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"549caf2f-232d-4a91-aa18-ed4504658a37","type":"DataRange1d"},"y_mapper_type":"auto","y_range":{"id":"bf2d08d8-5481-4824-85cd-94e205a6bec5" ...

# %% [markdown]
# # Using interactive sliders
# ---

# %%
# IMPORTS -------------------------------------------------

import numpy as np

from bokeh.layouts import row, widgetbox

from bokeh.models import CustomJS, Slider

from bokeh.plotting import figure, output_notebook, show, ColumnDataSource

# %% [markdown]
# # Experience Points
# ---

# %% [markdown]
# # Try to identify the purpose of these two functions:
#
# 1. CustomJS
# 1. Slider

# %%
# GENERATE FIGURE -----------------------------------------
plot = figure(y_range=(-10, 10), plot_width=400, plot_height=400)

# %%
# CREATE OR LOAD DATA/ENRICHMENTS -------------------------
x = np.linspace(0, 10, 500)
y = np.sin(x)
source = ColumnDataSource(data=dict(x=x, y=y))

# %%
# GENERATE GLYPHS -----------------------------------------
plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)
# Out:
# GlyphRenderer(id='9a379a90-d6bb-4307-9fe4-2f4e88527ba2', ...)

# %%
# ADD ATTRIBUTES, ANNOTATIONS, INTERACTIONS ---------------
# I am not a javascript guru.
# ... you are on your own in terms of making javascript


callback = CustomJS(args=dict(source=source), code="""
    var data = source.data;
    var A = amp.value;
    x = data['x']
    y = data['y']
    for (i = 0; i < x.length; i++) {
        y[i] = A*Math.sin(x[i]);
    }
    source.trigger('change');
    """)

amp_slider = Slider(start=0.1, end=10, value=1, step=.1,
                    title="Amplitude",
                    callback=callback)

callback.args["amp"] = amp_slider

layout = row(plot,
             widgetbox(amp_slider))

# %%
# CREATE OUTPUTS ------------------------------------------
output_notebook()
show(layout)

# http://bokeh.pydata.org/en/latest/docs/gallery/slider.html
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8b527997-1569-452d-b6bd-c0ab533073bd">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="03f20e89-ff8e-445b-a34b-50c0efa44cb4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("03f20e89-ff8e-445b-a34b-50c0efa44cb4");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("03f20e89-ff8e-445b-a34b-50c0efa44cb4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '03f20e89-ff8e-445b-a34b-50c0efa44cb4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2f522cb2-69f7-450f-97ac-74b8da226818":{"roots":{"references":[{"attributes":{},"id":"984a3caa-2dea-4af3-8a38-1d84ec67c44a","type":"ToolEvents"},{"attributes":{"callback":null},"id":"5e8cb627-8d69-4595-b85c-430a5e80d1f3","type":"DataRange1d"},{"attributes":{"plot":{"id":"34fe88b5-14e1-4e91-8a48-573481742728","subtype":"Figure","type":"Plot"}},"id":"6c80cd3b-5114-44e8-89de-332f584518f8","type":"WheelZoomTool"},{"attributes":{"args":{"amp":{"id":"b42869fe-06e2-4a98-8171-c6c41be69f92","type":"Slider"},"source":{"id":"5e139852-c9ac-4752-9fed-9314e671b157","type":"ColumnDataSource"}},"code":"\n    var data = source.data;\n    var A = amp.value;\n    x = data['x']\n    y = data['y']\n    for (i = 0; i < x.length; i++) {\n        y[i] = A*Math.sin(x[i]);\n    }\n    source.trigger('change');\n    "},"id":"b8439915-4f87-40b7-8396-cbcfc27ed378","type":"CustomJS"},{"attributes":{},"id":"c53a7567-ac3a-4a4a-8b0d-8388d42bbafb","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"fe04e7a1-d224-4325-b48a-dd6a31826d1d","type":"Line"},{"attributes":{"plot":null,"text":""},"id":"dc83923c-ae5f-41e6-9eb1-17d296f03038","type":"Title"},{"attributes":{"plot":{"id":"34fe88b5-14e1-4e91-8a48-573481742728","subtype":"Figure","type":"Plot"},"ticker":{"id":"38b41e80-f987-427c-ac71-63dd48ba7f7f","type":"BasicTicker"}},"id":"dd7319c2-bc7c-4233-892f-5782a9d2b48c","type":"Grid"},{"attributes":{"plot":{"id":"34fe88b5-14e1-4e91-8a48-573481742728","subtype":"Figure","type":"Plot"}},"id":"36f5b854-e6de-4707-9acb-5199567e3c8e","type":"ResetTool"},{"attributes":{"overlay":{"id":"699cbb62-b055-468d-83d1-32d61432c75d","type":"BoxAnnotation"},"plot":{"id":"34fe88b5-14e1-4e91-8a48-573481742728","subtype":"Figure","type":"Plot"}},"id":"f5d59597-c1db-4425-a7f6-4e4f63c9d375","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"5a18db7d-5ae0-4c70-99c2-2b4c0ac40960","type":"LinearAxis"}],"left":[{"id":"eca7b65f-e1c7-44a1-ae58-6a8454a06106","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"5a18db7d-5ae0-4c70-99c2-2b4c0ac40960","type":"LinearAxis"},{"id":"dd7319c2-bc7c-4233-892f-5782a9d2b48c","type":"Grid"},{"id":"eca7b65f-e1c7-44a1-ae58-6a8454a06106","type":"LinearAxis"},{"id":"6e21b370-05f3-413f-b05d-eca85bad35b9","type":"Grid"},{"id":"699cbb62-b055-468d-83d1-32d61432c75d","type":"BoxAnnotation"},{"id":"9a379a90-d6bb-4307-9fe4-2f4e88527ba2","type":"GlyphRenderer"}],"title":{"id":"dc83923c-ae5f-41e6-9eb1-17d296f03038","type":"Title"},"tool_events":{"id":"984a3caa-2dea-4af3-8a38-1d84ec67c44a","type":"ToolEvents"},"toolbar":{"id":"8ac49d2e-89f4-43f9-850d-56b2fcfcfe55","type":"Toolbar"},"x_range":{"id":"5e8cb627-8d69-4595-b85c-430a5e80d1f3","type":"DataRange1d"},"y_range":{"id":"e121e6a0-2a79-418c-82a7-80a6183cf863","type":"Range1d"}},"id":"34fe88b5-14e1-4e91-8a48-573481742728","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"38b41e80-f987-427c-ac71-63dd48ba7f7f","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"699cbb62-b055-468d-83d1-32d61432c75d","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"34fe88b5-14e1-4e91-8a48-573481742728","subtype":"Figure","type":"Plot"},"ticker":{"id":"c36e4f64-5b8e-4781-a031-59dab96ac5af","type":"BasicTicker"}},"id":"6e21b370-05f3-413f-b05d-eca85bad35b9","type":"Grid"},{"attributes":{"data_source":{"id":"5e139852-c9ac-4752-9fed-9314e671b157","type":"ColumnDataSource"},"glyph":{"id":"752dbf4f-33f3-4b15-b9a1-16e852259de0","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"fe04e7a1-d224-4325-b48a-dd6a31826d1d","type":"Line"},"sele ...

# %% [markdown]
# # Using visualization tools
# ---

# %%
# IMPORTS -------------------------------------------------

import numpy as np
from bokeh.plotting import figure, show, output_notebook

# %%
# CREATE OR LOAD DATA/ENRICHMENTS -------------------------

number = 4000
x = np.random.random(size=number) * 100     # random yields [0.0, 1.0) OR 0.0 <= x < 1.0
y = np.random.random(size=number) * 100

radii = np.random.random(size=number) * 1.5

# The following string formatting produces a hex number:
# %02x yields a zero padded hex number when you provide an integer
#     "#%02x" % (int(10)) would yield #0a
#     "#%02x%02x%02x" % (int(10), int(11), 150) would yield #0a0b96

colors = ["#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)]

# %%
# GENERATE FIGURE -----------------------------------------

TOOLS="crosshair,hover,pan,wheel_zoom,zoom_in,zoom_out,box_zoom,undo,redo,reset,tap,save,box_select,poly_select,lasso_select"

p = figure(tools=TOOLS)

# GENERATE GLYPHS -----------------------------------------

p.scatter(x, y, radius=radii,
          fill_color=colors, fill_alpha=0.8,
          line_color=None)


# CREATE OUTPUTS ------------------------------------------

output_notebook()
show(p)  # open a browser

# http://bokeh.pydata.org/en/latest/docs/gallery/color_scatter.html
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4fed2c94-dde1-4721-ad09-817dd564725e">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7d063b7c-6739-4716-9f45-ce957e7c5ca3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7d063b7c-6739-4716-9f45-ce957e7c5ca3");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7d063b7c-6739-4716-9f45-ce957e7c5ca3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7d063b7c-6739-4716-9f45-ce957e7c5ca3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1d4a45b3-9f66-421e-af08-bcf969bcaa71":{"roots":{"references":[{"attributes":{"overlay":{"id":"a3d630f5-299e-47b1-bcdd-1298eb86357e","type":"PolyAnnotation"},"plot":{"id":"8f7ed757-b7d3-45aa-99eb-7a04697734db","subtype":"Figure","type":"Plot"}},"id":"0f0d1da2-b051-4cf2-b5c0-f8834f0b03a8","type":"PolySelectTool"},{"attributes":{"plot":{"id":"8f7ed757-b7d3-45aa-99eb-7a04697734db","subtype":"Figure","type":"Plot"}},"id":"29cb81b7-4275-46b3-a772-12f99ab01495","type":"PanTool"},{"attributes":{"callback":null},"id":"ba687b7f-f18a-4899-a21f-6c10bd2bbd5a","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["radius","x","y","fill_color"],"data":{"fill_color":["#bc9996","#cb3996","#95a796","#5eb896","#e2e296","#d02e96","#d08096","#79c396","#536f96","#a82996","#895f96","#699796","#c6cb96","#d0cb96","#8b4b96","#dcb096","#9b9b96","#504996","#ba4696","#519396","#41bd96","#91e196","#c24c96","#868e96","#f29a96","#95bb96","#405496","#b37396","#8c4496","#8f8c96","#c9b496","#64bc96","#ba7696","#7fde96","#7ae296","#648e96","#acc896","#349b96","#553296","#7a5b96","#407d96","#499a96","#edd696","#5c6a96","#5e3496","#f89e96","#3ca196","#dad596","#586696","#4c7596","#e47096","#69bd96","#44d496","#666196","#9dbf96","#a57196","#572696","#6f4996","#687696","#7d5196","#84d296","#8d8696","#d3db96","#cadf96","#c3e096","#e08a96","#782796","#f69196","#f0d596","#516b96","#843696","#e33c96","#403496","#f82296","#bfc396","#f54f96","#9ebf96","#554696","#8ed796","#e38396","#b5b396","#4e7096","#b8e096","#ecc296","#ea5396","#a72596","#38a796","#477096","#95ab96","#398e96","#bcb496","#5bb696","#363f96","#8d6c96","#d65c96","#9f7a96","#87c496","#448b96","#742096","#a6c696","#77b196","#f29396","#a78b96","#9c8f96","#b95b96","#782296","#c6b096","#df2996","#66ad96","#adcf96","#c68d96","#c06196","#4dd296","#d02d96","#b66496","#ceb096","#a06e96","#6ab296","#4f6996","#987f96","#c3c496","#35c696","#695e96","#cc2996","#604696","#4fd896","#ab3d96","#60af96","#eaad96","#e34b96","#d19f96","#dd6596","#c65296","#61d296","#e5a496","#5c3496","#586196","#b5a696","#cca396","#4c7296","#8cd196","#8d2d96","#c1d896","#983396","#dc2696","#d62496","#94b796","#7d4c96","#c82796","#a5ad96","#934a96","#3d9e96","#f98396","#a56296","#afbb96","#c18896","#999a96","#f19e96","#8adc96","#d8a196","#738f96","#55b196","#e4df96","#ad6c96","#7ed096","#753d96","#9e6f96","#95d196","#41ae96","#326596","#37db96","#3fbf96","#e38c96","#f02d96","#ed6e96","#63a796","#6c3396","#389e96","#c83096","#a48996","#687696","#4b6896","#a82f96","#784496","#f65b96","#65db96","#c36396","#357796","#63ad96","#73ba96","#3b2796","#98c296","#f8c196","#469c96","#a29e96","#77cc96","#baa996","#516196","#c77696","#907196","#669f96","#e83396","#a86796","#557496","#597196","#cc1e96","#4c8196","#f7b396","#3b5796","#cb5496","#539e96","#54df96","#a5c096","#c24596","#692b96","#c74c96","#3e8d96","#b2b996","#af6c96","#c45296","#eb3a96","#c1d296","#a5ab96","#c57896","#da4396","#8f9196","#e0a396","#3cbb96","#b64296","#76c096","#c66896","#922496","#d7a996","#f92696","#581f96","#be4b96","#f78b96","#37c396","#cc2c96","#f6e496","#d59a96","#b84d96","#797196","#f87696","#6e4d96","#91d696","#cd8596","#649a96","#ba3a96","#6d8196","#c88c96","#622b96","#3cc796","#7b9a96","#69b396","#9f4496","#5cab96","#e7d496","#418c96","#404296","#c7ad96","#641f96","#c8bb96","#775a96","#60e096","#c87296","#e28296","#c24296","#bcc496","#6d3396","#8dd296","#48cd96","#c94c96","#c92b96","#8e7f96","#5dcc96","#67d996","#744996","#326696","#676596","#612096","#b15896","#ca2f96","#5c2296","#6cb496","#708f96","#c86996","#7ec196","#a15796","#d26096","#ed2a96","#7b5f96","#47b396","#576796","#9e5b96","#393a96","#615c96","#bd9896","#a57d96","#dac396","#3b8496","#cf7196","#962396","#e57596","#df6796","#70ac96","#344996","#66a596","#81ad96","#974296","#545996","#6e8696","#d57896","#403096","#a0a296","#824396","#d2b096","#359c96","#b37e96","#f4d396","#376e96","#43a596","#7d5f96","#a1b196","#bf9f96","#505696","#3f8c96","#402d96","#daba96","#5b9 ...

# %% [markdown]
# # Experience Points
# ---

# %% [markdown]
# Edit the code cell above to experiment with tool settings:
#
# 1. Add an **additional** `pan` tool to the TOOLS string and execute the code
#    * Consider the warning you get
#    * Look at the toolbar, anyway
#    * Remove the extra `pan` tool
# 1. Add the tool: `poly_select` to the TOOLS string and execute the code
# 1. Add the tool: `lasso_select` to the TOOLS string and execute the code

# %% [markdown]
# # Geographical map
# ---

# %%
# For larger datasets, we will need to download the data 

# The data will be stored in the following location:
# $home_directory/.bokeh/data

import bokeh
bokeh.sampledata.download()

# %%
# IMPORTS -------------------------------------------------

from bokeh.io import show
from bokeh.models import (
    ColumnDataSource,
    HoverTool,
    LogColorMapper
)

from bokeh.palettes import Viridis6 as palette
from bokeh.plotting import figure, output_notebook


from bokeh.sampledata.us_counties import data as counties
from bokeh.sampledata.unemployment import data as unemployment

# %%
# GENERATE FIGURE -----------------------------------------

TOOLS = "pan,wheel_zoom,box_zoom,reset,hover,save"

texas = figure(title="Texas Unemployment, 2009", 
               tools=TOOLS, 
               x_axis_location=None,
               y_axis_location=None)

texas.grid.grid_line_color = None

# %%
# Let's understand the data:
# Looking at just the first 20 keys from the counties data, we see that they are 
# tuples with the first number equal to 48
# the second number is an odd number

print(sorted(counties.keys())[:20])       
print()

# Looking at just one set of data for the county 
# coded with tuple 48, 3, we see that the data is a state, some lats and longs and some names.

print(counties[(48,3)])

# %%
# Looking at the data for unemployment:
# Each key is a tuple, some of which match the tuples for the counties
# Each tuple is paired with an unemployment value.

for key, value in sorted(unemployment.items()):
    if key[0] == 48:
        print('{}: {}'.format(key, value))

# %%
# CREATE OR LOAD DATA/ENRICHMENTS -------------------------

palette.reverse()

counties = {
    code: county for code, county in counties.items() if county["state"] == "tx"
}

county_xs = [county["lons"] for county in counties.values()]
county_ys = [county["lats"] for county in counties.values()]

county_names = [county['name'] for county in counties.values()]
county_rates = [unemployment[county_id] for county_id in counties]


# LogColorMapper will map numbers in a range [low, high] against a
# sequence of colors (i.e. a palette) on a natural logarithm scale.

color_mapper = LogColorMapper(palette=palette)

# ColumnDataSource() maps the names of columns to sequences or arrays,
# often using a dictionary OR DataFrame. Here we map all the values 
# of county_xs to a variable called x, etc.

source = ColumnDataSource(data=dict(
    x=county_xs,
    y=county_ys,
    name=county_names,
    rate=county_rates,
))

# %%
# GENERATE GLYPHS -----------------------------------------

# Here, we are referring to the 'x' and 'y' data found in the 
# ColumnDataSource we just created.
# Note that we use the string 'x' NOT x

texas.patches('x', 'y', source=source,
              fill_color={'field': 'rate', 'transform': color_mapper},
              fill_alpha=0.7, line_color="white", line_width=0.5)

# %%
# ADD ATTRIBUTES, ANNOTATIONS, INTERACTIONS ---------------

hover = texas.select_one(HoverTool)

hover.point_policy = "follow_mouse"

hover.tooltips = [("Name", "@name"),
                  ("Unemployment rate)", "@rate%"),
                  ("(Long, Lat)", "($x, $y)"),]

# %%
# CREATE OUTPUTS ------------------------------------------

output_notebook()
show(texas)

# http://bokeh.pydata.org/en/latest/docs/gallery/texas.html

# %% [markdown]
# # Experience Points
# ---

# %% [markdown]
# 1. On the Internets, research the syntax for generating tool tips.

# %% [markdown]
# ## Navigation
# ---
#
# | Previous | Up | Next |
# |:-----|:-----:|-----:|
# | <<< [First Graph](./first_graph.ipynb) | [Table of Contents](./README.md) | [What Went Wrong](./what_went_wrong.ipynb) >>> |
