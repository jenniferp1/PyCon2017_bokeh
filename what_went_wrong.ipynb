# %% [markdown]
# # Introduction to bokeh
#
# ## Wait, what? Why doesn't that work?
# ---
#
# <img src='./images/logos.3.600.wide.png' height='250' width='300' style="float:right">

# %% [markdown]
# Sometimes, things just don't work out...

# %% [markdown]
# # Some functions don't have help docstrings builtin, yet.
#
# 1. Read the Manual
# 1. `google` for it
# 1. Post a question to `stackoverflow.com`
# 1. Publish an issue to the bokeh github account
# 1. Create a fix, yourself AND get your fifteen minutes of fame.

# %% [markdown]
# # So what happens if I execute certain cells multiple times?
#
# It depends...
#
# Sometimes doing your science requires multiple iterations and you might be tempted to tweak a cell and `show()` results, tweak a cell and `show()` the results, etc...
#
# Unless you reset the figure (i.e. create a blank slate) you may not get what you want.
#
# When you execute a cell that produces glyphs, bokeh will start to accumulate the glyphs until you call `show()` again. Which means you may have multiple overlapping glyphs.

# %%
from bokeh.plotting import figure, show, output_notebook
import numpy as np
from random import choice

p = figure()

# %% [markdown]
# # Experience Points:
#
# 1. Run the following cell multiple times (i.e. five or six)
# 1. Once you have run it, then proceed to the following cell to see your graph.

# %%
color = choice(['red', 'green', 'blue', 'purple', 'black', 'orange', 'grey'])
x_values = [0, 1, 2, 3, 4, 5, 6]
y_values = np.random.randint(1, 20, 7)

p.line(x_values, y_values, line_color=color)
# Out:
# GlyphRenderer(id='c170c2c6-e680-4299-b923-4c0ad292ff79', ...)

# %%
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="97ad1958-56b5-4cc2-b821-c21cd7bed49b">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7beb0e4e-25bd-4da9-a6f2-cb52524cf487"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7beb0e4e-25bd-4da9-a6f2-cb52524cf487");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7beb0e4e-25bd-4da9-a6f2-cb52524cf487");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7beb0e4e-25bd-4da9-a6f2-cb52524cf487' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ae0f9743-a167-4cc6-85a4-720783e83255":{"roots":{"references":[{"attributes":{"overlay":{"id":"232b2500-e97e-4a40-9d6f-bf459e1d0824","type":"BoxAnnotation"},"plot":{"id":"fb465422-5e1e-4ea2-9724-8ba840ffc77d","subtype":"Figure","type":"Plot"}},"id":"3dd9ff4f-fb5f-413d-bbe1-c47acdc1b761","type":"BoxZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"fb465422-5e1e-4ea2-9724-8ba840ffc77d","subtype":"Figure","type":"Plot"},"ticker":{"id":"e20f73c7-55e1-4634-9aaf-c86dba210369","type":"BasicTicker"}},"id":"0062f472-724f-42aa-af47-60ebf7681ba7","type":"Grid"},{"attributes":{"line_color":{"value":"grey"},"x":{"field":"x"},"y":{"field":"y"}},"id":"17026092-372b-435a-b879-48b068cdbfea","type":"Line"},{"attributes":{},"id":"403cdee9-eb7b-4ea1-9111-52409573bd7f","type":"BasicTicker"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"75bfd7f9-ccb8-4c9f-9c1b-7bd12e9b33bd","type":"Line"},{"attributes":{"plot":null,"text":""},"id":"f8084645-1be8-460a-997d-0adfe924de37","type":"Title"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"232b2500-e97e-4a40-9d6f-bf459e1d0824","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"6a3bd881-3aa7-4408-90bc-8972fba46141","type":"DataRange1d"},{"attributes":{"callback":null},"id":"93435aa8-4ca4-498c-82e1-e339613886e6","type":"DataRange1d"},{"attributes":{"formatter":{"id":"b557b9d7-f412-453c-a9df-49d9c93ecf9e","type":"BasicTickFormatter"},"plot":{"id":"fb465422-5e1e-4ea2-9724-8ba840ffc77d","subtype":"Figure","type":"Plot"},"ticker":{"id":"403cdee9-eb7b-4ea1-9111-52409573bd7f","type":"BasicTicker"}},"id":"94bde258-c327-45d8-b5c1-433893899dd2","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2e680c21-7523-45a7-b08a-250a535f02b4","type":"PanTool"},{"id":"0b710b3e-8209-425f-b1b7-5ef6874c88f4","type":"WheelZoomTool"},{"id":"3dd9ff4f-fb5f-413d-bbe1-c47acdc1b761","type":"BoxZoomTool"},{"id":"087e19fc-677f-4c22-9257-23a558b853d6","type":"SaveTool"},{"id":"f5119546-53ab-4e89-b1d2-4621bbb29421","type":"ResetTool"},{"id":"9513c496-938d-416d-8f45-7296a1bad396","type":"HelpTool"}]},"id":"1af726f7-fc2c-476c-baa3-e0e8c06ad3f4","type":"Toolbar"},{"attributes":{},"id":"b557b9d7-f412-453c-a9df-49d9c93ecf9e","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"2a3e6826-3205-4675-bc78-ec330b8c959f","type":"BasicTickFormatter"},"plot":{"id":"fb465422-5e1e-4ea2-9724-8ba840ffc77d","subtype":"Figure","type":"Plot"},"ticker":{"id":"e20f73c7-55e1-4634-9aaf-c86dba210369","type":"BasicTicker"}},"id":"47311f44-8cd0-432c-bfd7-ed8302ee3388","type":"LinearAxis"},{"attributes":{"plot":{"id":"fb465422-5e1e-4ea2-9724-8ba840ffc77d","subtype":"Figure","type":"Plot"}},"id":"087e19fc-677f-4c22-9257-23a558b853d6","type":"SaveTool"},{"attributes":{},"id":"e20f73c7-55e1-4634-9aaf-c86dba210369","type":"BasicTicker"},{"attributes":{"data_source":{"id":"cda83bc1-7d17-4886-89e4-83ff8d172eb2","type":"ColumnDataSource"},"glyph":{"id":"75bfd7f9-ccb8-4c9f-9c1b-7bd12e9b33bd","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"91f9cb9a-ff25-48b8-8f3f-b418771b86d7","type":"Line"},"selection_glyph":null},"id":"1797eda9-850f-4b77-a580-26e3ace5e387","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"de955009-a8bc-4e20-aeaf-07d57b3cb968","type":"ColumnDataSource"},"glyph":{"id":"17026092-372b-435a-b879-48b068cdbfea","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"dca974cd-9f22-465a-ae97-25e284d9b692","type":"Line"},"selection_glyph":null},"id":"c170c2c6-e680-4299-b923-4c0ad292ff79","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"fb465422-5e1e-4ea2-9724-8ba840ffc77d ...

# %% [markdown]
# # refresh running servers
#
# Yeah... this got wonky.
#
# Let me tell you what happened.
#
# Never figured out why

# %% [markdown]
# # running code for servers
#
# This took an inordinate amount of time to figure out.

# %% [markdown]
# # internets access required, sorta...
#
# During a previous rendition of this tutorial, we lost all internet access pretty early on and that impacted some attendees ability to complete some tasks: their systems looked for, if I recall correctly, certain javascript libraries on the internet...
#
# If you find you need to host your code on systems that are connected to the internet, you should plan on testing your systems...

# %% [markdown]
# # output_file() you're killing me
#
# Upon running `output_file()` once in the notebook, other examples reused that reference and output files... especially if I was doing iterative development OR testing.
#
# Potentiallly **OVERWRITING** what I had already produced.
#
# Also: when running `output_file()` in Chrome, it opened in my default browser: Safari.

# %%
from bokeh.plotting import output_file

output_file('myresults.html')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2af5529e-cfcd-43a0-a819-b26ccf23475d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("2af5529e-cfcd-43a0-a819-b26ccf23475d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2af5529e-cfcd-43a0-a819-b26ccf23475d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2af5529e-cfcd-43a0-a819-b26ccf23475d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6d644e63-a433-4756-8ddf-330c25a236da":{"roots":{"references":[{"attributes":{"overlay":{"id":"232b2500-e97e-4a40-9d6f-bf459e1d0824","type":"BoxAnnotation"},"plot":{"id":"fb465422-5e1e-4ea2-9724-8ba840ffc77d","subtype":"Figure","type":"Plot"}},"id":"3dd9ff4f-fb5f-413d-bbe1-c47acdc1b761","type":"BoxZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"fb465422-5e1e-4ea2-9724-8ba840ffc77d","subtype":"Figure","type":"Plot"},"ticker":{"id":"e20f73c7-55e1-4634-9aaf-c86dba210369","type":"BasicTicker"}},"id":"0062f472-724f-42aa-af47-60ebf7681ba7","type":"Grid"},{"attributes":{"line_color":{"value":"grey"},"x":{"field":"x"},"y":{"field":"y"}},"id":"17026092-372b-435a-b879-48b068cdbfea","type":"Line"},{"attributes":{},"id":"403cdee9-eb7b-4ea1-9111-52409573bd7f","type":"BasicTicker"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"75bfd7f9-ccb8-4c9f-9c1b-7bd12e9b33bd","type":"Line"},{"attributes":{"plot":null,"text":""},"id":"f8084645-1be8-460a-997d-0adfe924de37","type":"Title"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"232b2500-e97e-4a40-9d6f-bf459e1d0824","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"6a3bd881-3aa7-4408-90bc-8972fba46141","type":"DataRange1d"},{"attributes":{"callback":null},"id":"93435aa8-4ca4-498c-82e1-e339613886e6","type":"DataRange1d"},{"attributes":{"formatter":{"id":"b557b9d7-f412-453c-a9df-49d9c93ecf9e","type":"BasicTickFormatter"},"plot":{"id":"fb465422-5e1e-4ea2-9724-8ba840ffc77d","subtype":"Figure","type":"Plot"},"ticker":{"id":"403cdee9-eb7b-4ea1-9111-52409573bd7f","type":"BasicTicker"}},"id":"94bde258-c327-45d8-b5c1-433893899dd2","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2e680c21-7523-45a7-b08a-250a535f02b4","type":"PanTool"},{"id":"0b710b3e-8209-425f-b1b7-5ef6874c88f4","type":"WheelZoomTool"},{"id":"3dd9ff4f-fb5f-413d-bbe1-c47acdc1b761","type":"BoxZoomTool"},{"id":"087e19fc-677f-4c22-9257-23a558b853d6","type":"SaveTool"},{"id":"f5119546-53ab-4e89-b1d2-4621bbb29421","type":"ResetTool"},{"id":"9513c496-938d-416d-8f45-7296a1bad396","type":"HelpTool"}]},"id":"1af726f7-fc2c-476c-baa3-e0e8c06ad3f4","type":"Toolbar"},{"attributes":{},"id":"b557b9d7-f412-453c-a9df-49d9c93ecf9e","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"2a3e6826-3205-4675-bc78-ec330b8c959f","type":"BasicTickFormatter"},"plot":{"id":"fb465422-5e1e-4ea2-9724-8ba840ffc77d","subtype":"Figure","type":"Plot"},"ticker":{"id":"e20f73c7-55e1-4634-9aaf-c86dba210369","type":"BasicTicker"}},"id":"47311f44-8cd0-432c-bfd7-ed8302ee3388","type":"LinearAxis"},{"attributes":{"plot":{"id":"fb465422-5e1e-4ea2-9724-8ba840ffc77d","subtype":"Figure","type":"Plot"}},"id":"087e19fc-677f-4c22-9257-23a558b853d6","type":"SaveTool"},{"attributes":{},"id":"e20f73c7-55e1-4634-9aaf-c86dba210369","type":"BasicTicker"},{"attributes":{"data_source":{"id":"cda83bc1-7d17-4886-89e4-83ff8d172eb2","type":"ColumnDataSource"},"glyph":{"id":"75bfd7f9-ccb8-4c9f-9c1b-7bd12e9b33bd","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"91f9cb9a-ff25-48b8-8f3f-b418771b86d7","type":"Line"},"selection_glyph":null},"id":"1797eda9-850f-4b77-a580-26e3ace5e387","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"de955009-a8bc-4e20-aeaf-07d57b3cb968","type":"ColumnDataSource"},"glyph":{"id":"17026092-372b-435a-b879-48b068cdbfea","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"dca974cd-9f22-465a-ae97-25e284d9b692","type":"Line"},"selection_glyph":null},"id":"c170c2c6-e680-4299-b923-4c0ad292ff79","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"fb465422-5e1e-4ea2-9724-8ba840ffc77d ...

# %%
# On my machine, when I create a new figure()
# and then attempt to show() the new figure...
# It ALSO attempts to write to the file myresults.html,
# overwriting my previous result.

h = figure()
show(h)

# %% [markdown]
# ## Navigation
# ---
#
# | Previous | Up | Next |
# |:-----|:-----:|-----:|
# | <<< [Five Fun Examples](./five_fun.ipynb) |[Table of Contents](./README.md) | [Servers](./servers.ipynb) >>> |
