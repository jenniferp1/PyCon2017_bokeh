# %% [markdown]
# # Introduction to bokeh
#
# ## Picture this, your first basic graph
# ---
#
# <img src='./images/logos.3.600.wide.png' height='250' width='300' style="float:right">

# %% [markdown]
# # Creating a basic graph
# ---

# %%
from bokeh.plotting import figure, show, output_notebook

x_values = [0, 1, 2, 3, 4, 5, 6, 19]
y_values = [0.0, 1.0, 1.4, 1.7, 2.0, 2.2, 2.4]

p = figure()

p.line(y_values, x_values)

output_notebook()
show(p)
# Out:
# C:\Users\JP\Anaconda3\envs\python35\lib\site-packages\bokeh\models\sources.py:89: BokehUserWarning: ColumnDataSource's columns must be of the same length
#   lambda: warnings.warn("ColumnDataSource's columns must be of the same length", BokehUserWarning))
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="36a16b2a-61ad-4f5a-858c-0780405b8e64">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f4540656-4605-4cf4-8ad8-06b44f234b4c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f4540656-4605-4cf4-8ad8-06b44f234b4c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f4540656-4605-4cf4-8ad8-06b44f234b4c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f4540656-4605-4cf4-8ad8-06b44f234b4c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e149fe62-99d9-4563-943a-e30eb86230fc":{"roots":{"references":[{"attributes":{"formatter":{"id":"a8bcc2da-a673-489a-a023-afbdce0b492b","type":"BasicTickFormatter"},"plot":{"id":"b9ed25aa-3648-4cd6-ac79-3bf4d748c6e0","subtype":"Figure","type":"Plot"},"ticker":{"id":"2f1d2fa9-f4c7-4785-93d7-86b2f445a77d","type":"BasicTicker"}},"id":"a1b55208-0480-4ce3-afd7-5d9c5de20f5c","type":"LinearAxis"},{"attributes":{"plot":{"id":"b9ed25aa-3648-4cd6-ac79-3bf4d748c6e0","subtype":"Figure","type":"Plot"}},"id":"c8885112-44c7-466d-a735-3c3acdee9bbc","type":"SaveTool"},{"attributes":{"plot":null,"text":""},"id":"316aa514-4e74-4eb4-8d9a-9488d68fa06a","type":"Title"},{"attributes":{"plot":{"id":"b9ed25aa-3648-4cd6-ac79-3bf4d748c6e0","subtype":"Figure","type":"Plot"}},"id":"a662887d-9545-40dd-af05-72af721026d7","type":"HelpTool"},{"attributes":{"dimension":1,"plot":{"id":"b9ed25aa-3648-4cd6-ac79-3bf4d748c6e0","subtype":"Figure","type":"Plot"},"ticker":{"id":"2f1d2fa9-f4c7-4785-93d7-86b2f445a77d","type":"BasicTicker"}},"id":"431c0219-d8d4-46aa-9ebe-afee75ae716a","type":"Grid"},{"attributes":{},"id":"a8bcc2da-a673-489a-a023-afbdce0b492b","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"b9ed25aa-3648-4cd6-ac79-3bf4d748c6e0","subtype":"Figure","type":"Plot"}},"id":"1cd797c8-6716-4668-b348-e4837d8feea6","type":"PanTool"},{"attributes":{},"id":"98855dec-06d2-4216-9162-7ec15f27f605","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"90c82146-3b22-4031-a2b4-b6631c62ced2","type":"ColumnDataSource"},"glyph":{"id":"b289e0de-f1aa-4354-8b70-8e8d77f29a41","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"17d49349-41f6-4782-9149-e7d59802eee6","type":"Line"},"selection_glyph":null},"id":"e0774148-f642-488e-a6cd-d2a78c4016dc","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"b88709ae-e3f2-499d-86e4-3d662c76cf17","type":"LinearAxis"}],"left":[{"id":"a1b55208-0480-4ce3-afd7-5d9c5de20f5c","type":"LinearAxis"}],"renderers":[{"id":"b88709ae-e3f2-499d-86e4-3d662c76cf17","type":"LinearAxis"},{"id":"2dc08b6f-5ad8-42e5-9d3f-22f7b192941c","type":"Grid"},{"id":"a1b55208-0480-4ce3-afd7-5d9c5de20f5c","type":"LinearAxis"},{"id":"431c0219-d8d4-46aa-9ebe-afee75ae716a","type":"Grid"},{"id":"b2fe1459-3c24-4a12-bfd8-52bb9d155daf","type":"BoxAnnotation"},{"id":"e0774148-f642-488e-a6cd-d2a78c4016dc","type":"GlyphRenderer"}],"title":{"id":"316aa514-4e74-4eb4-8d9a-9488d68fa06a","type":"Title"},"tool_events":{"id":"7d4343b9-2f85-4204-8f00-5d2a175771b1","type":"ToolEvents"},"toolbar":{"id":"4e4237f6-75af-48df-920b-a4dde4feb42c","type":"Toolbar"},"x_range":{"id":"e46938b5-cc67-4e16-a879-61031b3ce476","type":"DataRange1d"},"y_range":{"id":"a138c652-c8d3-44ce-9446-3e352f038370","type":"DataRange1d"}},"id":"b9ed25aa-3648-4cd6-ac79-3bf4d748c6e0","subtype":"Figure","type":"Plot"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b289e0de-f1aa-4354-8b70-8e8d77f29a41","type":"Line"},{"attributes":{},"id":"13af0044-ffa5-4ff2-bde7-b1e1df546d5f","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.0,1.0,1.4,1.7,2.0,2.2,2.4],"y":[0,1,2,3,4,5,6,19]}},"id":"90c82146-3b22-4031-a2b4-b6631c62ced2","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"17d49349-41f6-4782-9149-e7d59802eee6","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b2fe1459-3c24-4a12-bfd8-52bb9d155daf","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"b9ed25aa-3648-4cd6-ac79-3bf4d748c6e0","subtype":"Figure","type":"Plot"},"ticker":{"id":"13af0044-ffa5-4ff2-bde7-b1e1df546d5f","type":"BasicTick ...

# %%
import bokeh.plotting
bokeh.plotting.output_file?

# %% [markdown]
# # Get an error related to numpy?
# ## Are you on Windows?
#
# This [comment thread](https://github.com/ContinuumIO/anaconda-issues/issues/883), albeit related to scipy, may help.

# %% [markdown]
# # Experience Points
# ---

# %% [markdown]
# In the code cell above, try the following experiments:
#
# 1. Add an additional number to `x_values` and to `y_values` and execute the cell (press `Ctrl+Enter`)
# 1. Swap the `x_values` and `y_values` (i.e. change `p.line(...)` to `p.line(y_values, x_values)` and execute the cell
# 1. Add an additional value to the `x_values`, but leave the `y_values` alone, so that the number of elements is no longer the same, and execute the cell

# %% [markdown]
# # Getting help
# ---

# %% [markdown]
# ```python
# object?
# ```
#
# For example:
#
# ```python
# p?
# ```

# %%
p?

# %% [markdown]
# # Don't know what functions are available?
# ---

# %% [markdown]
# `p.<tab-complete>`

# %%
p.

# %% [markdown]
# # Want insight into what a _particular_ function can do?
# ---

# %% [markdown]
# `p.line?`

# %%
p.line?

# %% [markdown]
# # Experience Points
# ---

# %% [markdown]
# In the code cell above, use IPython help to read about the `p.line` method:
#
# 1. **DON'T FRET** if some of it feels like gibberish OR certain words or phrases are unclear.
#
# 1. This exercise is more about familiarizing you with what is available. Plus, many of these are found associated with every type of glyph, so you will see them over and over again and your familiarity will grow over time.
#
# 1. **NOTE:** I am not an expert on all of the parameters associated with the various glyphs, so don't fret if there seems to be a lot to learn.

# %% [markdown]
# # Let's do it again, but moar!
# ---
#
# ## with Circles
# ## with Dashes
# ## with Legends

# %%
from bokeh.plotting import figure, show, output_notebook
import numpy as np

moar = figure()

x = np.linspace(0.1, 5, 100)               # figures can handle numpy arrays
y = range(0, 200, 2)                       # and ranges()

# Let's use circular markers and a dotted and dashed line
# AND 
# add a legend with unique entries for each line

moar.circle(x, np.cumsum(x),
            legend="y=cumsum(y)")

moar.line(x, y, 
          legend="y=range(0, 200, 2)",
          line_color="#663399", line_dash="dotdash")

# And add a legend created from the legend attributes of each item

moar.legend.location = "top_left"

output_notebook()
show(moar)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="368e5650-c342-4f62-a233-3054ba79754d">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fc199753-da15-4c05-a425-d31a384877a4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("fc199753-da15-4c05-a425-d31a384877a4");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fc199753-da15-4c05-a425-d31a384877a4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fc199753-da15-4c05-a425-d31a384877a4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8f0fab42-6c1d-479e-967a-b719b41c9331":{"roots":{"references":[{"attributes":{},"id":"93c93722-f4c7-4edc-b7fb-76850b387a06","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"aeebfe5e-e75b-4275-8414-f05e7ddffa8e","subtype":"Figure","type":"Plot
e","subtype":"Figure","type":"Plot"},"ticker":{"id":"90055da2-edd2-4e79-93b0-693fabd17d51","type":"BasicTicker"}},"id":"8443073c-96d8-49b4-b9d6-2ae9816b9213","type":"Grid"},{"attributes":{"label":{"value":"y=cumsum(y)"},"renderers":[{"id":"33e9fe66-6b35-4193-b94a-5fdbd98e0704","type":"GlyphRenderer"}]},"id":"09afd8f4-ae65-4b35-ae11-ae9c0efd5f66" ...

# %% [markdown]
# # How to learn more, in these notebooks
# ---

# %% [markdown]
# 1. Select the cell in the notebook that contains something you want to learn more about
# 1. Click the `Insert cell below` button (the `plus` sign) on the Jupyter toolbar to make an empty cell
# <img src='./images/jupyter_toolbar.png' width='300' style="float:center"><br>
# 1. Inspect the variables and methods/functions
#    * `print()` the variable (or a subset of the variable)
#    * Use the `type()` function to figure out what type of object you have
#    * Use the question mark help functionality (`object?`) to learn more about the object
#    * Tweak something, see what happens.

# %% [markdown]
# # Moarest! adding multiple features to a basic graph
# ---

# %% [markdown]
# ## Colors
#
# Bokeh has rich support for colors using the most common color schemas.
#
# * any of the 147 named CSS colors, e.g `green`, `indigo`, `purple`
# * hex values: Red, Green, Blue (optional Alpha) >>> RGB(A) e.g., `#FF0000`, `#44444444`
# * a 3-tuple of integers (R, G, B) between 0 and 255
# * a 4-tuple of (R, G, B, A) where R, G, B are integers between 0 and 255 and A is a floating point value between 0 and 1
#
# ## What colors and color names?
# [https://en.wikipedia.org/wiki/Web_colors](https://en.wikipedia.org/wiki/Web_colors)

# %%
from bokeh.plotting import figure, show, output_file, output_notebook
import numpy as np

x = np.linspace(0.1, 5, 100)
y = x

# Add a title
# Define the type of y-axis
# Set the range of values for the y-axis

p = figure(title="log axis example", 
           y_axis_type="log", y_range=(0.001, 10**22))

# %%
# Set the fill color for our circles to None

p.circle(x, y**2, legend="y=x**2", 
         fill_color=None, 
         line_color="blueviolet", size=5)
# Out:
# GlyphRenderer(id='cd3edc7f-60df-469d-ba3a-ce662058e7f1', ...)

# %%
# Create a line
# Set the line width to 4

p.line(x, 10**y, legend="y=10^x", line_color="darkred", 
       line_width=2)
# Out:
# GlyphRenderer(id='91452837-76f8-48a4-b92c-4e1ed5ddde9d', ...)

# %%
# Add a line composed of squares
# Use hex this time to color the line

p.square(x, 10**(x**2), legend="y=10^(x^2)",
       line_color="#663399", 
       line_dash="solid", line_width=2)
# Out:
# GlyphRenderer(id='b67366a1-5022-4659-9ee5-1fea52dc45ff', ...)

# %%
# Move the legend location
# Change the legend font

p.legend.location = "center_left"
p.legend.label_text_font='times'

# Change characteristics of the title text (color, font, font-style)
# Using RGB tuple this time

p.title.text_font_size = '16pt'
p.title.text_color = (125, 125, 125)
p.title.text_font = "courier"
p.title.text_font_style = "bold"

# Set the background color

p.background_fill_color = "whitesmoke"

# %%
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="33bc7428-8bbc-46e5-aefa-9a87335c01b4">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="395e0c31-9da1-438c-af10-9d3ad04fec12"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("395e0c31-9da1-438c-af10-9d3ad04fec12");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("395e0c31-9da1-438c-af10-9d3ad04fec12");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '395e0c31-9da1-438c-af10-9d3ad04fec12' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a
Renderer"},{"id":"91452837-76f8-48a4-b92c-4e1ed5ddde9d","type":"GlyphRenderer"},{"id":"b67366a1-5022-4659-9ee5-1fea52dc45ff","type":"GlyphRenderer"}],"title":{"id":"f657aafd-e66c-4d51-a7e7-32627a3ae293","type":"Title"},"tool_events":{"id":"b5b61aa3-1771-4523-9507-a59a14ed6aa0","type":"ToolEvents"},"toolbar":{"id":"280c4139-aeb5-4c65-a3a1-8c1d1aba1fcb","type":"Toolbar"},"x_range":{"id":"83f483b3-e9b4-4909-8559-8abbc2f4fd8c","type":"DataRange1d"},"y_mapper_type":"log","y_range":{"id":"d54a6cde-13f2-4232-bd87-41c6a251a70a","type":"Range1d"}},"id":"5bfb48a9-c050-41fd-8bf0-a6639f841db5","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"5bfb48a9-c050-41fd-8bf0-a6639f841 ...

# %% [markdown]
# # Color Palettes
# ---

# %% [markdown]
# http://bokeh.pydata.org/en/latest/docs/reference/palettes.html
#
# <img src='./images/purples.png' height='250' width='300' style="float:right">

# %%
from bokeh.palettes import Purples

# Internally, palettes such as Purples are stored as dictionaries:

# Key: integer indicating how many colors are in a sub palette
# Value: list of strings indicating the actual color values 

print(Purples[3], Purples[5], sep='\n', end='\n\n')

line_color = Purples[5][1]      # '#756bb1'

print("line_color:", line_color)
# Out:
# ['#756bb1', '#bcbddc', '#efedf5']
# ['#54278f', '#756bb1', '#9e9ac8', '#cbc9e2', '#f2f0f7']
#
# line_color: #756bb1

# %%
# Let's add a new line to the figure
# This one will use a dot-dash appearance and
# the color we chose above, from the Palette

p.line(x, np.sqrt(x) * 100, 
       legend="y=sqrt(x)", 
       line_color=line_color, 
       line_dash="dotdash", 
       line_width=3)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ee6b3f8d-a8e4-4bd9-94e2-29c438cf19e5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ee6b3f8d-a8e4-4bd9-94e2-29c438cf19e5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ee6b3f8d-a8e4-4bd9-94e2-29c438cf19e5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ee6b3f8d-a8e4-4bd9-94e2-29c438cf19e5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3f15e947-0abc-487a-af7b-fde2616c2845":{"roots":{"references":[{"attributes":{"plot":{"id":"5bfb48a9-c050-41fd-8bf0-a6639f841db5","subtype":"Figure","type":"Plot"},"ticker":{"id":"b71f7946-31b7-4f35-bcc3-91cf90d79409","type":"BasicTicker"}},"id":"c6a673ff-41e7-467d-95ce-002b8cdeaf90","type":"Grid"},{"attributes":{"ticker":null},"id":"8ace5ef0-fede-4ffc-851f-aec24b385004","type":"LogTickFormatter"},{"attributes":{"plot":{"id":"5bfb48a9-c050-41fd-8bf0-a6639f841db5","subtype":"Figure","type":"Plot"}},"id":"19cdb088-640b-4703-8deb-c1721d992ffd","type":"ResetTool"},{"attributes":{"data_source":{"id":"d12c5819-ce8c-4191-986d-0b3c91e99950","type":"ColumnDataSource"},"glyph":{"id":"7364bc1e-a008-4514-942a-a2c8e05ca305","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"7388e83a-aed7-4125-b4b4-a413c442aa81","type":"Line"},"selection_glyph":null},"id":"95b6e138-875f-484f-909c-9e100a4bce68","type":"GlyphRenderer"},{"attributes":{},"id":"b5b61aa3-1771-4523-9507-a59a14ed6aa0","type":"ToolEvents"},{"attributes":{"line_color":{"value":"darkred"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":